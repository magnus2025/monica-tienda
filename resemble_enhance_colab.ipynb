# %% [markdown]
# <a href="https://colab.research.google.com/github/magnus2025/monica-tienda/blob/main/resemble_enhance_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Instalar Python 3.10 en Colab
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils python3.10-venv -y
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,972 kB]
# ...

# %%
# Paso 2: Configurar Python 3.10 como la versión por defecto de python3
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.11   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.11   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 1
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode

# %%
# Paso 3: Instalar pip para Python 3.10
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pip]
# ...

# %%
# Paso 4: Verifica la versión de Python (debería mostrar Python 3.10.X)
# !python3 --version
# Out:
# Python 3.10.12

# %%
# %cd /content
# !git clone https://huggingface.co/spaces/ResembleAI/resemble-enhance
# %cd /content/resemble-enhance
# !!pip install --upgrade pip

# !pip install -r requirements.txt
# !pip install matplotlib_inline ipython


# !pip install -U gradio==4.8.0
# !gradio==4.43.0
# !fastapi==0.112.4
# !gradio-client==1.3.0
# !pydantic==2.9.0
# !pydantic-core==2.23.2

# !python app.py
# Out:
# /content
# fatal: destination path 'resemble-enhance' already exists and is not an empty directory.
# /content/resemble-enhance
# ...
# WARNING: typer 0.15.4 does not provide the extra 'all'
# ...
# WARNING: typer 0.15.4 does not provide the extra 'all'
# ...
# /bin/bash: line 1: gradio-client==1.3.0: command not found
# /bin/bash: line 1: pydantic-core==2.23.2: command not found
# [2025-05-23 22:13:33,834] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 4.8.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://9507d99b4893d90174.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Already up to date.
# ^C
